# %%
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open("human_detection.json", "r") as f:
    human_dections = json.load(f)


def draw_bboxes(bboxes, image):
    for bbox in bboxes:
        image = cv2.rectangle(image, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (255, 0, 0), 2)
    return image


def change_bbox_format(bboxes):
    changed_bboxes = []
    for bbox in bboxes:
        x1 = int(bbox[0])
        y1 = int(bbox[1])
        x2 = int(x1 + bbox[2])
        y2 = int(y1 + bbox[3])
        changed_bboxes.append([x1, y1, x2, y2])
    return changed_bboxes


def adjust_bbox(bboxes):
    # bboxes = change_bbox_format(bboxes)
    bboxes = np.asarray(bboxes)
    x1 = bboxes[:, 0]
    y1 = bboxes[:, 1]
    x2 = bboxes[:, 2]
    y2 = bboxes[:, 3]
    new_bbox = [min(x1), min(y1), max(x2), max(y2)]
    return new_bbox


def change_bbox_hw(bboxes):
    changed_bboxes = []
    for bbox in bboxes:
        x1 = int(bbox[0])
        y1 = int(bbox[1])
        x2 = int(bbox[2] - x1)
        y2 = int(bbox[3] - y1)
        changed_bboxes.append([x1, y1, x2, y2])
    return changed_bboxes


def cal_avg_bbox(bboxes):
    changed_bbox = bboxes.copy()
    for i in range(15, len(bboxes) - 15):
        sub_bboxes = bboxes[i-15:i+15]
        if i == 145:
            print(sub_bboxes)
        adj_bbox = adjust_bbox(sub_bboxes)
        changed_bbox[i] = adj_bbox
    return changed_bbox
    

def collect_bbox(human_detections):
    bboxes = []
    for detection in human_dections:
        bboxes.append(detection["bbox"])
    return bboxes
    


bboxes = collect_bbox(human_detections=human_dections)
bboxes = change_bbox_format(bboxes=bboxes)
sub_bboxes = change_bbox_hw(cal_avg_bbox(bboxes=bboxes))

for i in range(len(human_dections)):
    human_dections[i]["bbox"] = sub_bboxes[i]

with open("human_detection.json", "w") as f:
    json.dump(human_dections, fp=f)

# img = cv2.cvtColor(cv2.imread("videoframes/frame000145.jpg"), cv2.COLOR_BGR2RGB)
# img_rec = draw_bboxes(bboxes=sub_bboxes, image=img.copy())
# new_bbox = adjust_bbox(bboxes=sub_bboxes)
# print(new_bbox)
# img_rec = cv2.rectangle(img_rec, (new_bbox[0], new_bbox[1]), (new_bbox[2], new_bbox[3]), (0, 255, 0), 3)
# Out:
# [[362, 57, 435, 278], [361, 57, 432, 284], [353, 58, 406, 322], [350, 60, 403, 330], [363, 56, 433, 296], [364, 55, 438, 286], [360, 54, 445, 283], [357, 54, 441, 272], [358, 53, 441, 275], [362, 53, 447, 269], [361, 53, 438, 267], [363, 54, 441, 267], [367, 54, 438, 266], [364, 55, 439, 270], [362, 55, 444, 265], [359, 53, 439, 265], [360, 54, 439, 265], [360, 54, 438, 265], [358, 54, 438, 268], [358, 55, 440, 263], [359, 55, 432, 266], [357, 55, 435, 263], [357, 55, 433, 263], [356, 55, 433, 263], [358, 55, 434, 262], [359, 55, 433, 262], [361, 56, 434, 262], [359, 56, 439, 260], [358, 56, 436, 262], [359, 56, 440, 262]]

# %%
len(human_dections)
# Out:
# 797

# %%
print(human_dections[15])
# Out:
# {'image_id': 'frame000015.jpg', 'category_id': 1, 'bbox': [339.8978042602539, 61.609036445617676, 82.55348205566406, 251.9645643234253], 'score': 0.5035306215286255}

# %%
print(sub_bboxes[145])
# Out:
# [350, 53, 447, 330]

# %%
sub_bboxes[145]
# Out:
# [350, 53, 447, 330]

# %%
x1 = 312
y1=48
x2=447
y2=335

# %%
img_rec = img = cv2.cvtColor(cv2.imread("videoframes/frame000145.jpg"), cv2.COLOR_BGR2RGB)
plt.imshow(cv2.rectangle(img_rec, (x1, y1), (x2, y2), (0, 0, 255), 3))
